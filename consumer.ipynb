# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloGP10/Hola_Mundo/blob/main/consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
data=pd.read_excel('consumer_mit_lift_lab.xlsx')
data.head(10)
# Out:
#                              _record_id             _title  \
# 0  94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1  1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2  3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3  335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4  902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# 5  23c8e9f7-3099-41da-aac4-05d2185e1733  November 27, 2022
# 6  a494aa93-9568-4a39-bcdd-e4e7e45c6d7e  November 18, 2022
# 7  ed23476c-2787-4d5d-8fcc-3f1ae6518321  November 26, 2022
# 8  bee0a85f-07e7-487b-a399-c5093a7bb36d  November 27, 2022
# 9  e8749cc5-86d5-479c-858d-07da7cfe21b5  November 27, 2022
#
#         _server_updated_at             _updated_by  \
# 0  2022-11-27 19:17:26 UTC          Sandra Carreón
# 1  2022-11-27 19:17:26 UTC          Sandra Carreón
# 2  2022-11-27 19:00:55 UTC          Sandra Carreón
# 3  2022-11-27 18:51:26 UTC          Sandra Carreón
# 4  2022-11-27 16:03:02 UTC          Sandra Carreón
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                            352
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store               363
# 301_electricity_bill                          0
# 305_electricity_bill_store                   29
# 302_water_bill                                0
# 306_water_bill_store                         14
# 303_gas_bill                                  0
# 307_gas_bill_store                            7
# ...

# %% [markdown]
# **Métodos de Sustitución de Valores Nulos**

# %%
#Realizamos una copia del dataframe
data2=data.copy()

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto 
data2["300_did_not_find"]= data2["300_did_not_find"].fillna("encontro todo") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store               363
# 301_electricity_bill                          0
# 305_electricity_bill_store                   29
# 302_water_bill                                0
# 306_water_bill_store                         14
# 303_gas_bill                                  0
# 307_gas_bill_store                            7
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["284_additional_products_store"]= data2["284_additional_products_store"].fillna("ninguno") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                   29
# 302_water_bill                                0
# 306_water_bill_store                         14
# 303_gas_bill                                  0
# 307_gas_bill_store                            7
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["305_electricity_bill_store"]= data2["305_electricity_bill_store"].fillna("yes") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                    0
# 302_water_bill                                0
# 306_water_bill_store                         14
# 303_gas_bill                                  0
# 307_gas_bill_store                            7
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["306_water_bill_store"]= data2["306_water_bill_store"].fillna("yes") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                    0
# 302_water_bill                                0
# 306_water_bill_store                          0
# 303_gas_bill                                  0
# 307_gas_bill_store                            7
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["307_gas_bill_store"]= data2["307_gas_bill_store"].fillna("yes") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                    0
# 302_water_bill                                0
# 306_water_bill_store                          0
# 303_gas_bill                                  0
# 307_gas_bill_store                            0
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["308_topups_in_store"]= data2["308_topups_in_store"].fillna("no") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                    0
# 302_water_bill                                0
# 306_water_bill_store                          0
# 303_gas_bill                                  0
# 307_gas_bill_store                            0
# ...

# %%
data2["309_wiretransfers_in_store"] =data2["309_wiretransfers_in_store"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                    0
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# _geometry                                     0
# _latitude                                     0
# _longitude                                    0
# 282_payment_method_that_purchase              0
# 283_fulfill_needs                             0
# 300_did_not_find                              0
# 237_distance_household_interviewee            0
# 299_means_transportation_consumer             0
# 238_frequency_buying_store                    0
# 284_additional_products_store                 0
# 301_electricity_bill                          0
# 305_electricity_bill_store                    0
# 302_water_bill                                0
# 306_water_bill_store                          0
# 303_gas_bill                                  0
# 307_gas_bill_store                            0
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
data2["304_additional_services_store"]= data2["304_additional_services_store"].fillna("Pago con tarjeta") 
data2
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# _record_id                                   0
# _title                                       0
# _server_updated_at                           0
# _updated_by                                  0
# _geometry                                    0
# _latitude                                    0
# _longitude                                   0
# 282_payment_method_that_purchase             0
# 283_fulfill_needs                            0
# 300_did_not_find                             0
# 237_distance_household_interviewee           0
# 299_means_transportation_consumer            0
# 238_frequency_buying_store                   0
# 284_additional_products_store                0
# 301_electricity_bill                         0
# 305_electricity_bill_store                   0
# 302_water_bill                               0
# 306_water_bill_store                         0
# 303_gas_bill                                 0
# 307_gas_bill_store                           0
# ...

# %%
#Eliminamos columnas innecesarias
data3= data2.drop(['storefront_picture_just_once_if_possible'], axis=1)
data3
# Out:
#                                _record_id             _title  \
# 0    94c9c1c8-f806-4dd6-9124-0447101139ce  November 27, 2022
# 1    1766c0a9-8f4d-452e-b2f9-5c7f7fa6e509  November 27, 2022
# 2    3f1e53cb-d761-48aa-be19-18d69ecbebf2  November 27, 2022
# 3    335e6647-537c-47da-9efa-805a110f6936  November 27, 2022
# 4    902e4d41-8299-424d-834b-d1090b1743c0  November 27, 2022
# ..                                    ...                ...
# 370  ee7ac407-4767-47b1-93b3-d7e09b49faec   November 3, 2022
# 371  f65a8190-df80-440e-83bc-2639decfffd0   November 3, 2022
# 372  70f42238-83b5-4a16-9f2e-a758efb8afb0   November 3, 2022
# 373  e4727f46-797f-4344-b183-0deeed11750f   November 3, 2022
# 374  0a5616e1-62cd-4f28-a282-9b34db145752   November 3, 2022
#
#           _server_updated_at                _updated_by  \
# 0    2022-11-27 19:17:26 UTC             Sandra Carreón
# 1    2022-11-27 19:17:26 UTC             Sandra Carreón
# 2    2022-11-27 19:00:55 UTC             Sandra Carreón
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# _record_id                             0
# _title                                 0
# _server_updated_at                     0
# _updated_by                            0
# _geometry                              0
# _latitude                              0
# _longitude                             0
# 282_payment_method_that_purchase       0
# 283_fulfill_needs                      0
# 300_did_not_find                       0
# 237_distance_household_interviewee     0
# 299_means_transportation_consumer      0
# 238_frequency_buying_store             0
# 284_additional_products_store          0
# 301_electricity_bill                   0
# 305_electricity_bill_store             0
# 302_water_bill                         0
# 306_water_bill_store                   0
# 303_gas_bill                           0
# 307_gas_bill_store                     0
# 286_topups                             0
# 308_topups_in_store                    0
# 287_wire_transfers                     0
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# **Outliers**

# %%
y=data3

# %%
#Identificamos las variables no numéricas para eliminar columnas incecesarias 
#Verificamos información del DataFrame
y.info(9)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   _latitude                            375 non-null    float64
#  1   _longitude                           375 non-null    float64
#  2   238_frequency_buying_store           375 non-null    int64
#  3   81_number_online_purchases_month     375 non-null    int64
#  4   288_number_app_purchases_month       375 non-null    int64
#  5   289_number_whatsapp_purchases_month  375 non-null    int64
#  6   83_willingness_ultrafast_delivery    375 non-null    int64
#  7   84_willingness_sameday_delivery      375 non-null    int64
#  8   241_age_of_the_interviewee           375 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 26.5 KB

# %%
#aplicamos filtro de columnas para filtrar las columnas con variables numéricas (se descartaron las columnas que muestran números de telofóno y las coordenadas) 
y1=data3.iloc[:,[5,6,12,26,27,28,29,30,31,]]#columnas no consecutivas
y1
# Out:
#      _latitude  _longitude  238_frequency_buying_store  \
# 0    19.048665  -98.198087                           1
# 1    19.048704  -98.198059                           2
# 2    19.045914  -98.201741                           2
# 3    19.048590  -98.198122                           3
# 4    19.044148  -98.198825                           2
# ..         ...         ...                         ...
# 370  19.035224  -98.267100                           1
# 371  19.035280  -98.267856                           1
# 372  19.035451  -98.267862                           1
# 373  19.035486  -98.267831                           1
# 374  19.035399  -98.267924                           1
#
#      81_number_online_purchases_month  288_number_app_purchases_month  \
# 0                                   5                               4
# 1                                   5                               3
# 2                                   9                              12
# ...

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=y1

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido _latitude                               19.092051
# _longitude                             -98.116677
# 238_frequency_buying_store               6.000000
# 81_number_online_purchases_month         7.500000
# 288_number_app_purchases_month          12.500000
# 289_number_whatsapp_purchases_month      2.500000
# 83_willingness_ultrafast_delivery      145.000000
# 84_willingness_sameday_delivery        235.000000
# 241_age_of_the_interviewee              73.500000
# dtype: float64
# Limite inferior permitido _latitude                               18.976260
# _longitude                             -98.346358
# 238_frequency_buying_store              -2.000000
# 81_number_online_purchases_month        -4.500000
# 288_number_app_purchases_month          -7.500000
# 289_number_whatsapp_purchases_month     -1.500000
# 83_willingness_ultrafast_delivery      -55.000000
# 84_willingness_sameday_delivery       -125.000000
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= y1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#      _latitude  _longitude  238_frequency_buying_store  \
# 0          NaN         NaN                         NaN
# 1          NaN         NaN                         NaN
# 2          NaN         NaN                         NaN
# 3          NaN         NaN                         NaN
# 4          NaN         NaN                         NaN
# ..         ...         ...                         ...
# 370        NaN         NaN                         NaN
# 371        NaN         NaN                         NaN
# 372        NaN         NaN                         NaN
# 373        NaN         NaN                         NaN
# 374        NaN         NaN                         NaN
#
#      81_number_online_purchases_month  288_number_app_purchases_month  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 9.0                             NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= y1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#      _latitude  _longitude  238_frequency_buying_store  \
# 0    19.048665  -98.198087                         1.0
# 1    19.048704  -98.198059                         2.0
# 2    19.045914  -98.201741                         2.0
# 3    19.048590  -98.198122                         3.0
# 4    19.044148  -98.198825                         2.0
# ..         ...         ...                         ...
# 370  19.035224  -98.267100                         1.0
# 371  19.035280  -98.267856                         1.0
# 372  19.035451  -98.267862                         1.0
# 373  19.035486  -98.267831                         1.0
# 374  19.035399  -98.267924                         1.0
#
#      81_number_online_purchases_month  288_number_app_purchases_month  \
# 0                                 5.0                             4.0
# 1                                 5.0                             3.0
# 2                                 NaN                            12.0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# _latitude                               0
# _longitude                              0
# 238_frequency_buying_store             11
# 81_number_online_purchases_month       14
# 288_number_app_purchases_month         17
# 289_number_whatsapp_purchases_month    51
# 83_willingness_ultrafast_delivery      46
# 84_willingness_sameday_delivery        13
# 241_age_of_the_interviewee              3
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#      _latitude  _longitude  238_frequency_buying_store  \
# 0    19.048665  -98.198087                         1.0
# 1    19.048704  -98.198059                         2.0
# 2    19.045914  -98.201741                         2.0
# 3    19.048590  -98.198122                         3.0
# 4    19.044148  -98.198825                         2.0
# ..         ...         ...                         ...
# 370  19.035224  -98.267100                         1.0
# 371  19.035280  -98.267856                         1.0
# 372  19.035451  -98.267862                         1.0
# 373  19.035486  -98.267831                         1.0
# 374  19.035399  -98.267924                         1.0
#
#      81_number_online_purchases_month  288_number_app_purchases_month  \
# 0                                 5.0                             4.0
# 1                                 5.0                             3.0
# 2                                 1.9                            12.0
# ...

# %%
Union=data3
Datos_limpios=pd.concat([Union,y1],axis=1)
Datos_limpios

# %%
#convertir a archivo xlsx
Datos_limpios.to_csv("consumer_Limpio.csv")

# %%
#descargar archivo filtrado en xlsx
from google.colab import files 
  
files.download("consumer_Limpio.csv")
