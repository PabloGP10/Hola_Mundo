# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloGP10/Hola_Mundo/blob/main/Copia_de_6__Regresion_lineal_Multiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde seaborn
df=sns.load_dataset(name='car_crashes')
df.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
#Se grafican mapas de dispersion de las variables 3 ariables 'alcohol','speeding' y 'no previous'
from turtle import color
sns.scatterplot(x='not_distracted',y='total',color='blue',data=df)
#sns.scatterplot(x='speeding',y='total',color='red',data=df)
#sns.scatterplot(x='no_previous',y='total',color='yellow',data=df)

# %%
#Declaramos las variables dependientes (y) e independientes (x) paara la regresion lineal
Vars_Indep=df[['not_distracted']]
Var_Dep=df['total']

# %%
#Se define model como la función de regresion lineal
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#Verificmaos la funcion relacionada al modelo
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
#Ajustamos el modelocon las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modeloajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['not_distracted'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.75653646]),
#  '_residues': 267.7289245486287,
#  'rank_': 1,
#  'singular_': array([31.88328273]),
#  'intercept_': 5.5215931626388794}

# %%
#Eavluamos la eficiencia del modelo obtendio por eido del coeficiene R determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.6848561363410162

# %% [markdown]
# **Modelo Predictivo**

# %%
#Predecimos los valores de total de accidentes a partir de las variables: alcohol,
y_pred=model.predict(X=df[['not_distracted']])
y_pred
# Out:
# array([19.17556324, 17.84557214, 17.34171886, 21.45122492, 13.78297134,
#        13.64982092, 12.63000977, 16.18421807,  9.98515829, 17.98023563,
#        16.73346354, 16.3778914 , 15.36034986, 14.62423988, 15.94288294,
#        17.04288695, 15.89068192, 18.1496998 , 16.84316133, 15.46021267,
#        12.23585427, 10.91872429, 15.65539908, 11.9128132 ,  6.85309734,
#        16.72741125, 19.12109262, 16.00491893, 16.08662487, 13.15655915,
#        12.80855237, 14.84817468, 13.71034384, 17.46881698, 23.42200241,
#        16.08208565, 19.37226272, 12.00964987, 18.73979824, 13.24734352,
#        22.87956576, 19.90486439, 17.6186112 , 18.87748788, 13.04459175,
#        15.39893322, 13.88056454, 12.0974081 , 22.98699394,  9.59327241,
#        16.18421807])

# %%
#Insertamos la columna de predicciones en el dataframe
df.insert(0,'Predicciones',y_pred)
df
# Out:
#     Predicciones  total  speeding  alcohol  not_distracted  no_previous  \
# 0      19.175563   18.8     7.332    5.640          18.048       15.040
# 1      17.845572   18.1     7.421    4.525          16.290       17.014
# 2      17.341719   18.6     6.510    5.208          15.624       17.856
# 3      21.451225   22.4     4.032    5.824          21.056       21.280
# 4      13.782971   12.0     4.200    3.360          10.920       10.680
# 5      13.649821   13.6     5.032    3.808          10.744       12.920
# 6      12.630010   10.8     4.968    3.888           9.396        8.856
# 7      16.184218   16.2     6.156    4.860          14.094       16.038
# 8       9.985158    5.9     2.006    1.593           5.900        5.900
# 9      17.980236   17.9     3.759    5.191          16.468       16.826
# 10     16.733464   15.6     2.964    3.900          14.820       14.508
# 11     16.377891   17.5     9.450    7.175          14.350       15.225
# 12     15.360350   15.3     5.508    4.437          13.005       14.994
# 13     14.624240   12.8     4.608    4.352          12.032       12.288
# 14     15.942883   14.5     3.625    4.205          13.775       13.775
# 15     17.042887   15.7     2.669    3.925          15.229       13.659
# 16     15.890682   17.8     4.806    4.272          13.706       15.130
# 17     18.149700   21.4     4.066    4.922          16.692       16.264
# 18     16.843161   20.5     7.175    6.765          14.965       20.090
# 19     15.460213   15.1     5.738    4.530          13.137       12.684
# 20     12.235854   12.5     4.250    4.000           8.875       12.375
# 21     10.918724    8.2     1.886    2.870           7.134        6.560
# 22     15.655399   14.1     3.384    3.948          13.395       10.857
# 23     11.912813    9.6     2.208    2.784           8.448        8.448
# 24      6.853097   17.6     2.640    5.456           1.760       17.600
# 25     16.727411   16.1     6.923    5.474          14.812       13.524
# 26     19.121093   21.4     8.346    9.416          17.976       18.190
# 27     16.004919   14.9     1.937    5.215          13.857       13.410
# 28     16.086625   14.7     5.439    4.704          13.965       14.553
# 29     13.156559   11.6     4.060    3.480          10.092        9.628
# 30     12.808552   11.2     1.792    3.136           9.632        8.736
# 31     14.848175   18.4     3.496    4.968          12.328       18.032
# 32     13.710344   12.3     3.936    3.567          10.824        9.840
# 33     17.468817   16.8     6.552    5.208          15.792       13.608
# 34     23.422002   23.9     5.497   10.038          23.661       20.554
# 35     16.082086   14.1     3.948    4.794          13.959       11.562
# 36     19.372263   19.9     6.368    5.771          18.308       18.706
# 37     12.009650   12.8     4.224    3.328           8.576       11.520
# 38     18.739798   18.2     9.100    5.642          17.472       16.016
# 39     13.247344   11.1     3.774    4.218          10.212        8.769
# 40     22.879566   23.9     9.082    9.799          22.944       19.359
# 41     19.904864   19.4     6.014    6.402          19.012       16.684
# 42     17.618611   19.5     4.095    5.655          15.990       15.795
# 43     18.877488   19.4     7.760    7.372          17.654       16.878
# 44     13.044592   11.3     4.859    1.808           9.944       10.848
# 45     15.398933   13.6     4.080    4.080          13.056       12.920
# 46     13.880565   12.7     2.413    3.429          11.049       11.176
# 47     12.097408   10.6     4.452    3.498           8.692        9.116
# 48     22.986994   23.8     8.092    6.664          23.086       20.706
# 49      9.593272   13.8     4.968    4.554           5.382       11.592
# 50     16.184218   17.4     7.308    5.568          14.094       15.660
#
#     ins_premium  ins_losses abbrev
# 0        784.55      145.08     AL
# 1       1053.48      133.93     AK
# 2        899.47      110.35     AZ
# 3        827.34      142.39     AR
# 4        878.41      165.63     CA
# 5        835.50      139.91     CO
# 6       1068.73      167.02     CT
# 7       1137.87      151.48     DE
# 8       1273.89      136.05     DC
# 9       1160.13      144.18     FL
# 10       913.15      142.80     GA
# 11       861.18      120.92     HI
# 12       641.96       82.75     ID
# 13       803.11      139.15     IL
# 14       710.46      108.92     IN
# 15       649.06      114.47     IA
# 16       780.45      133.80     KS
# 17       872.51      137.13     KY
# 18      1281.55      194.78     LA
# 19       661.88       96.57     ME
# 20      1048.78      192.70     MD
# 21      1011.14      135.63     MA
# 22      1110.61      152.26     MI
# 23       777.18      133.35     MN
# 24       896.07      155.77     MS
# 25       790.32      144.45     MO
# 26       816.21       85.15     MT
# 27       732.28      114.82     NE
# 28      1029.87      138.71     NV
# 29       746.54      120.21     NH
# 30      1301.52      159.85     NJ
# 31       869.85      120.75     NM
# 32      1234.31      150.01     NY
# 33       708.24      127.82     NC
# 34       688.75      109.72     ND
# 35       697.73      133.52     OH
# 36       881.51      178.86     OK
# 37       804.71      104.61     OR
# 38       905.99      153.86     PA
# 39      1148.99      148.58     RI
# 40       858.97      116.29     SC
# 41       669.31       96.87     SD
# 42       767.91      155.57     TN
# 43      1004.75      156.83     TX
# 44       809.38      109.48     UT
# 45       716.20      109.61     VT
# 46       768.95      153.72     VA
# 47       890.03      111.62     WA
# 48       992.61      152.56     WV
# 49       670.31      106.62     WI
# 50       791.14      122.04     WY

# %%
#visualizamos la grafica comparativa entre el total real y el total predecido
sns.scatterplot(x='not_distracted',y='total',color='blue',data=df)
sns.scatterplot(x='not_distracted',y='Predicciones',color='red',data=df)
#sns.lineplot(x='alcohol',y='Predicciones',color='yellow',data=df)

# %%
#Corroboramos cual es el coeficiente de determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.6848561363410162

# %%
#Coroboramos cuel es el coeficiente de corrrelacion de nuestro modelo
coef_correl=np.sqrt(coef_Deter)
coef_correl
# Out:
# 0.8275603520837717
